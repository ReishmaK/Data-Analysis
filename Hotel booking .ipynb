# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
# Load the file #

# %%
df = pd.read_csv('/Users/reishmak/Downloads/hotel_booking_data.txt', delimiter='\t')
df.head()
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
# Companies #

# %%
df['Company'].value_counts()
# Out:
# Leexo           3
# Fivechat        3
# Quinu           3
# Rhynyx          2
# Jabbersphere    2
#                ..
# Oloo            1
# Miboo           1
# Geba            1
# Centidel        1
# Buzzdog         1
# Name: Company, Length: 114, dtype: int64

# %%
# Remove NaN #

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
# Calculate 2xRoom #

# %%
df['2xRoom'] = df['Room number']*2
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
# [195 rows x 5 columns]

# %%
# Create another dataframe and remove NaN #

# %%
df2 = df.dropna()
df2.head()
# Out:
#          Date Company          Person Name  Room number  2xRoom
# 0  1-Jan-2022  Avamba    Anatole Ridehalgh       4008.0  8016.0
# 1  1-Jan-2022    Fatz      Aldrich McKevin       2002.0  4004.0
# 2  1-Jan-2022   Leexo      Stanley Hadrill       4012.0  8024.0
# 4  1-Jan-2022  Rhyzio         Lyndell Tice       1006.0  2012.0
# 5  1-Jan-2022   Eadel  Broderic Handscombe       3015.0  6030.0

# %%
# To find the NaN , if Nan then True , else False/Value #

# %%
df['Room number'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194     True
# Name: Room number, Length: 195, dtype: bool

# %%
# Store it in a new variable "mask" and create new column #
# np.nan will fill the empty cells #

# %%
mask = df['Room number'].isna()
df['Text Value'] = np.where(mask, df['Date'],np.nan)#np.nan =""#
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4          NaN
# ..         ...
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#            Date       Company          Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0   8024.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 4      Booking
# ...

# %%
# To update the Text Values Nan and fill in the back direction #

# %%
df['Text Value'].fillna(method='bfill', inplace=True)
df
# Out:
#            Date       Company        Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0   8024.0
# 3        Hotels           NaN                NaN          NaN      NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0   2012.0
# ..          ...           ...                ...          ...      ...
# 190   Cleartrip           NaN                NaN          NaN      NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0   2020.0
# 194      Hotels           NaN                NaN          NaN      NaN
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 3       Hotels
# 4      Booking
# ..         ...
# ...

# %%
# Clean the data / Remove the Nan #

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number   2xRoom  \
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0   8016.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0   4004.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0   8024.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0   2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0   6030.0
# ..          ...           ...                  ...          ...      ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0   2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0  14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0   8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0  10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0   2020.0
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 4      Booking
# ...

# %%
# Count the companies #

# %%
df.value_counts('Text Value')
# Out:
# Text Value
# Expedia             48
# Hotels              39
# Booking             24
# Travel Agent 007    12
# Cleartrip           11
# dtype: int64

# %%
# Bar Graph #

# %%
df3 = df.value_counts('Text Value')
df3.plot(kind='bar', figsize = (15,8))
plot.ylabel('Counts')
plot.title('Hotel Booking')
# Out:
# Text(0.5, 1.0, 'Hotel Booking')
